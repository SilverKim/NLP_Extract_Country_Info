# %% [markdown]
# ### Daeun Kim (Candidate of JPA), AI and Data Engineer

# %%
import requests
import pandas as pd
import re
from tqdm import tqdm
import spacy
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data part

# %%
# Base API endpoint
api_endpoint = 'https://search.worldbank.org/api/v2/wds'

# Parameters for the API request
params = {
    'format': 'json',
    'fct': 'docty_exact,count_exact,lang_exact,disclstat_exact',
    'rows': 500,  # Max rows per request
    'apilang': 'en',
    'str_docdt': '2010-01-01',
    'end_docdt': '2024-07-01',
    'majdocty_key': '906674',  # Economic and Sector Work (ESW)
    'order': 'desc',
    'os': 0,  
    'srt': 'docdt',
    'lang_key':'120701',  # English
}

# Initialize variables
all_documents = []
offset = 0
rows_per_request = 500  # Adjust based on API limitations

# First request to get the total number of records
params['os'] = offset
response = requests.get(api_endpoint, params=params)
data = response.json()

total_records = int(data['total'])
print(f'Total records found: {total_records}')

# Fetch all records
while offset < total_records:
    params['os'] = offset
    response = requests.get(api_endpoint, params=params)
    data = response.json()
    documents = data.get('documents', {})
    for doc_id, doc_info in documents.items():
        all_documents.append(doc_info)
    offset += rows_per_request
    print(f'Fetched {len(all_documents)} records so far...')

print(f'Total records fetched: {len(all_documents)}')
# Out:
# Total records found: 2920
# Fetched 501 records so far...
# Fetched 1002 records so far...
# Fetched 1503 records so far...
# Fetched 2004 records so far...
# Fetched 2505 records so far...
# Fetched 2926 records so far...
# Total records fetched: 2926

# %%
df = pd.DataFrame(columns=['id','title','year'])

for doc in tqdm(all_documents):
    title = doc.get('display_title')
    date = doc.get('docdt')
    id = doc.get('id')

    df = pd.concat([df, pd.DataFrame({'id': [id],'title': [title], 'year': [date] })],ignore_index=True)

df.head()
# Out:
# 100%|██████████| 2926/2926 [00:00<00:00, 9747.46it/s]
#          id                                              title  \
# 0  34366193           Suriname - Poverty and Equity Assessment
# 1  34369413                           Serbia Policy Notes 2024
# 2  34351433  Maldives - Country Climate and\n            De...
# 3  34354089  Microfinance in the Kyrgyz Republic\n         ...
# 4  34354258  Operational Note - How to use the\n           ...
#
#                    year
# 0  2024-07-01T00:00:00Z
# 1  2024-06-30T00:00:00Z
# 2  2024-06-30T00:00:00Z
# 3  2024-06-28T00:00:00Z
# 4  2024-06-28T00:00:00Z

# %%
df.isna().sum()
# Out:
# id       6
# title    6
# year     6
# dtype: int64

# %%
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df.isna().sum()
# Out:
# id       0
# title    0
# year     0
# dtype: int64

# %%
def clean_text(text):
    text = re.sub(r'\n', '', text)
    text = text.replace('  ', ' ')
    return text.strip()

df['title'] = df['title'].apply(clean_text)

# %%
df.head()
# Out:
#          id                                              title  \
# 0  34366193           Suriname - Poverty and Equity Assessment
# 1  34369413                           Serbia Policy Notes 2024
# 2  34351433  Maldives - Country Climate and      Developmen...
# 3  34354089  Microfinance in the Kyrgyz Republic      : Pov...
# 4  34354258  Operational Note - How to use the      Bulsho ...
#
#                    year
# 0  2024-07-01T00:00:00Z
# 1  2024-06-30T00:00:00Z
# 2  2024-06-30T00:00:00Z
# 3  2024-06-28T00:00:00Z
# 4  2024-06-28T00:00:00Z

# %%
'''
import nltk
import locationtagger

nltk.downloader.download('maxent_ne_chunker')
nltk.downloader.download('words')
nltk.downloader.download('treebank')
nltk.download('maxent_ne_chunker_tab')
nltk.downloader.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')

df['country'] = None

for i in tqdm(range(len(df))):
    text = df.loc[i, 'title']

    # Extract country names
    location_ent = locationtagger.find_locations(text = text)

    if location_ent.countries:
        df.loc[i, 'country'] = location_ent.countries[0]


df.head()
'''

# %%
nlp = spacy.load('en_core_web_trf')

# add a country column to the dataframe
df['country'] = None

# extract country names from the title
for i in tqdm(range(len(df))):
    try:
        title = df.loc[i,'title']
    except Exception as e:
        print(df.loc[i])

    doc = nlp(title)
    for ent in doc.ents:
        if ent.label_ == 'LOC':
            df.loc[i,'country'] = ent.text
            break
        if ent.label_ == 'GPE':
            df.loc[i,'country'] = ent.text
            break
# Out:
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:253: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filelike, map_location=device))
#   0%|          | 0/2920 [00:00<?, ?it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   0%|          | 1/2920 [00:00<12:05,  4.02it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   0%|          | 3/2920 [00:00<05:10,  9.38it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   0%|          | 5/2920 [00:00<03:50, 12.66it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   0%|          | 7/2920 [00:00<03:18, 14.68it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   0%|          | 9/2920 [00:00<03:02, 15.98it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   0%|          | 12/2920 [00:00<02:44, 17.65it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   1%|          | 15/2920 [00:00<02:31, 19.23it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   1%|          | 18/2920 [00:01<02:21, 20.50it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   1%|          | 21/2920 [00:01<02:27, 19.59it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   1%|          | 23/2920 [00:01<02:35, 18.58it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   1%|          | 25/2920 [00:01<02:36, 18.52it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   1%|          | 27/2920 [00:01<02:52, 16.75it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   1%|          | 30/2920 [00:01<02:35, 18.60it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   1%|          | 32/2920 [00:01<02:35, 18.58it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   1%|          | 35/2920 [00:02<02:35, 18.55it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   1%|▏         | 37/2920 [00:02<02:35, 18.51it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   1%|▏         | 40/2920 [00:02<02:29, 19.23it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   1%|▏         | 43/2920 [00:02<02:20, 20.45it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   2%|▏         | 46/2920 [00:02<02:18, 20.68it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   2%|▏         | 52/2920 [00:02<02:15, 21.19it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   2%|▏         | 55/2920 [00:02<02:18, 20.72it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   2%|▏         | 58/2920 [00:03<02:13, 21.38it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   2%|▏         | 61/2920 [00:03<02:13, 21.40it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   2%|▏         | 64/2920 [00:03<02:14, 21.23it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   2%|▏         | 67/2920 [00:03<02:15, 21.10it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   2%|▏         | 70/2920 [00:03<02:09, 22.08it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   2%|▎         | 73/2920 [00:03<02:06, 22.55it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   3%|▎         | 76/2920 [00:03<02:08, 22.17it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   3%|▎         | 79/2920 [00:04<02:08, 22.05it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   3%|▎         | 82/2920 [00:04<02:13, 21.28it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   3%|▎         | 85/2920 [00:04<02:18, 20.42it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   3%|▎         | 88/2920 [00:04<02:14, 21.12it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   3%|▎         | 91/2920 [00:04<02:14, 21.04it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   3%|▎         | 94/2920 [00:04<02:12, 21.35it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   3%|▎         | 97/2920 [00:04<02:12, 21.33it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   3%|▎         | 100/2920 [00:05<02:04, 22.68it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   4%|▎         | 103/2920 [00:05<02:00, 23.41it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   4%|▎         | 106/2920 [00:05<02:00, 23.30it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   4%|▎         | 109/2920 [00:05<02:01, 23.22it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   4%|▍         | 112/2920 [00:05<02:04, 22.58it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   4%|▍         | 118/2920 [00:05<02:18, 20.21it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   4%|▍         | 121/2920 [00:06<02:15, 20.72it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   4%|▍         | 124/2920 [00:06<02:11, 21.21it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   4%|▍         | 127/2920 [00:06<02:06, 22.15it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   4%|▍         | 130/2920 [00:06<02:10, 21.43it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   5%|▍         | 133/2920 [00:06<02:14, 20.73it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   5%|▍         | 136/2920 [00:06<02:10, 21.36it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   5%|▍         | 139/2920 [00:06<02:05, 22.20it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   5%|▍         | 142/2920 [00:06<02:02, 22.72it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   5%|▍         | 145/2920 [00:07<01:59, 23.20it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   5%|▌         | 148/2920 [00:07<02:00, 23.02it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   5%|▌         | 151/2920 [00:07<02:02, 22.62it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   5%|▌         | 154/2920 [00:07<02:01, 22.74it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   5%|▌         | 157/2920 [00:07<02:02, 22.51it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   5%|▌         | 160/2920 [00:07<02:02, 22.46it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   6%|▌         | 163/2920 [00:07<02:06, 21.85it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   6%|▌         | 166/2920 [00:08<02:04, 22.06it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   6%|▌         | 169/2920 [00:08<02:03, 22.27it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   6%|▌         | 172/2920 [00:08<02:03, 22.21it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   6%|▌         | 175/2920 [00:08<02:05, 21.95it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   6%|▌         | 178/2920 [00:08<02:05, 21.88it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   6%|▌         | 181/2920 [00:08<02:00, 22.65it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   6%|▋         | 184/2920 [00:08<01:56, 23.42it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   6%|▋         | 187/2920 [00:08<01:57, 23.31it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   7%|▋         | 190/2920 [00:09<01:55, 23.56it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   7%|▋         | 193/2920 [00:09<01:57, 23.25it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   7%|▋         | 196/2920 [00:09<01:55, 23.54it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   7%|▋         | 199/2920 [00:09<01:55, 23.48it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   7%|▋         | 202/2920 [00:09<02:03, 22.03it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   7%|▋         | 205/2920 [00:09<02:00, 22.59it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   7%|▋         | 208/2920 [00:09<02:00, 22.47it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   7%|▋         | 211/2920 [00:10<01:57, 23.10it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   7%|▋         | 214/2920 [00:10<01:57, 23.07it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   7%|▋         | 217/2920 [00:10<01:54, 23.62it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   8%|▊         | 220/2920 [00:10<01:55, 23.28it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#   8%|▊         | 223/2920 [00:10<01:56, 23.19it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# ...
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  98%|█████████▊| 2852/2920 [02:16<00:04, 16.47it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  98%|█████████▊| 2855/2920 [02:16<00:03, 18.24it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  98%|█████████▊| 2858/2920 [02:17<00:03, 19.56it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  98%|█████████▊| 2860/2920 [02:17<00:03, 18.63it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  98%|█████████▊| 2863/2920 [02:17<00:02, 19.31it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  98%|█████████▊| 2865/2920 [02:17<00:03, 18.23it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  98%|█████████▊| 2867/2920 [02:17<00:03, 16.40it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  98%|█████████▊| 2870/2920 [02:17<00:02, 18.42it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  98%|█████████▊| 2873/2920 [02:17<00:02, 19.46it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  98%|█████████▊| 2875/2920 [02:17<00:02, 17.09it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  99%|█████████▊| 2878/2920 [02:18<00:02, 18.75it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  99%|█████████▊| 2881/2920 [02:18<00:02, 19.45it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  99%|█████████▊| 2883/2920 [02:18<00:02, 17.94it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  99%|█████████▉| 2886/2920 [02:18<00:01, 19.10it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  99%|█████████▉| 2889/2920 [02:18<00:01, 20.64it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  99%|█████████▉| 2895/2920 [02:18<00:01, 20.80it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  99%|█████████▉| 2901/2920 [02:19<00:00, 22.08it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
#  99%|█████████▉| 2904/2920 [02:19<00:00, 20.99it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# 100%|█████████▉| 2907/2920 [02:19<00:00, 21.44it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# 100%|█████████▉| 2910/2920 [02:19<00:00, 21.73it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# 100%|█████████▉| 2913/2920 [02:19<00:00, 21.32it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# 100%|█████████▉| 2916/2920 [02:19<00:00, 22.06it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# /Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# 100%|█████████▉| 2919/2920 [02:20<00:00, 22.98it/s]/Users/dek/anaconda3/envs/wb/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# 100%|██████████| 2920/2920 [02:20<00:00, 20.85it/s]

# %%
df.loc[~df['country'].isna()].shape
df.head(10)
# Out:
#          id                                              title  \
# 0  34366193           Suriname - Poverty and Equity Assessment
# 1  34369413                           Serbia Policy Notes 2024
# 2  34351433  Maldives - Country Climate and      Developmen...
# 3  34354089  Microfinance in the Kyrgyz Republic      : Pov...
# 4  34354258  Operational Note - How to use the      Bulsho ...
# 5  34354314  A Local Social Contract Platform for      Soma...
# 6  34351594  Unleashing Aspirations While      Ensuring Opp...
# 7  34351724  Maghreb PASA Synthesis Policy Note -      Magh...
# 8  34350917  Green, Resilient, Inclusive, and      Learning...
# 9  34350771  Paraguay - Country Economic      Memorandum : ...
#
#                    year              country
# 0  2024-07-01T00:00:00Z             Suriname
# 1  2024-06-30T00:00:00Z               Serbia
# 2  2024-06-30T00:00:00Z                 None
# 3  2024-06-28T00:00:00Z  the Kyrgyz Republic
# 4  2024-06-28T00:00:00Z              Somalia
# 5  2024-06-28T00:00:00Z              Somalia
# 6  2024-06-27T00:00:00Z        Latin America
# 7  2024-06-27T00:00:00Z                 None
# 8  2024-06-26T00:00:00Z               Brazil
# 9  2024-06-26T00:00:00Z                 None

# %%
import plotly.express as px

# %%
valid_data = df.loc[~df['year'].isna()]
valid_data = valid_data.loc[~valid_data['country'].isna()]

# %%
valid_data.shape
# Out:
# (2270, 4)

# %%
valid_data.head()
# Out:
#          id                                              title  \
# 0  34366193           Suriname - Poverty and Equity Assessment
# 1  34369413                           Serbia Policy Notes 2024
# 3  34354089  Microfinance in the Kyrgyz Republic      : Pov...
# 4  34354258  Operational Note - How to use the      Bulsho ...
# 5  34354314  A Local Social Contract Platform for      Soma...
#
#                    year              country
# 0  2024-07-01T00:00:00Z             Suriname
# 1  2024-06-30T00:00:00Z               Serbia
# 3  2024-06-28T00:00:00Z  the Kyrgyz Republic
# 4  2024-06-28T00:00:00Z              Somalia
# 5  2024-06-28T00:00:00Z              Somalia

# %%
doc_counts = valid_data.groupby(['country', 'year']).size().reset_index(name='count')
doc_counts.head()
# Out:
#        country                  year  count
# 0        Accra  2010-06-01T00:00:00Z      1
# 1         Aden  2012-01-01T00:00:00Z      1
# 2  Afghanistan  2010-01-01T00:00:00Z      1
# 3  Afghanistan  2010-04-01T00:00:00Z      2
# 4  Afghanistan  2011-02-01T00:00:00Z      1

# %%
doc_counts['year'] = pd.to_datetime(doc_counts['year']).dt.year
print(doc_counts[['year']].head()) 
print(doc_counts['year'].unique())

# Calculate the number of documents (publications) per year
total_docs_per_year = doc_counts.groupby('year')['count'].transform('sum')
print(total_docs_per_year.head()) 

# Calculate percentage
doc_counts['percentage'] = (doc_counts['count'] / total_docs_per_year) * 100
print(doc_counts[['year', 'country', 'count', 'percentage']].head())
# Out:
#    year
# 0  2010
# 1  2012
# 2  2010
# 3  2010
# 4  2011
# [2010 2012 2011 2013 2014 2015 2017 2024 2022 2018 2019 2021 2020 2023
#  2016]
# 0    373
# 1    252
# 2    373
# 3    373
# 4    264
# Name: count, dtype: int64
#    year      country  count  percentage
# 0  2010        Accra      1    0.268097
# 1  2012         Aden      1    0.396825
# 2  2010  Afghanistan      1    0.268097
# 3  2010  Afghanistan      2    0.536193
# 4  2011  Afghanistan      1    0.378788

# %% [markdown]
# ### Visualization Part

# %%
#save file 
#doc_counts.to_csv('doc_counts.csv', index=False)

# %%
# use file
'''
import pandas as pd

doc_counts = pd.read_csv('doc_counts.csv')
doc_counts['year'] = pd.to_datetime(doc_counts['year']).dt.year
doc_counts.head()
'''

# %%
# percentage - bar
import plotly.express as px

year_order = list(range(2010, 2025))
doc_counts['year'] = pd.Categorical(doc_counts['year'], categories=year_order, ordered=True)

fig_percentage = px.bar(
    doc_counts,
    x='country',
    y='percentage',
    animation_frame='year',
    animation_group='country',
    color='country',
    range_y=[0, doc_counts['percentage'].max()],  # 퍼센티지는 항상 0에서 100 사이
    title='Evolution of the Percentage of Documents by Country and Year',
    labels={'percentage': 'Percentage of Documents (%)', 'country': 'Country'},
    category_orders={"year": year_order}
)

# update layout
fig_percentage.update_layout(
    height=800,
    width=1200,
    showlegend=False,  
    transition={'duration': 50},
    xaxis={'categoryorder': 'total descending'}, #sequence
)

fig_percentage.layout.updatemenus[0].buttons[0].args[1]['frame']['redraw'] = False
fig_percentage.layout.updatemenus[0].buttons[0].args[1]['mode'] = 'immediate'


fig_percentage.frames = sorted(fig_percentage.frames, key=lambda frame: int(frame.name))
fig_percentage.show()

# %%
# percentage - pi
import plotly.graph_objects as go
import pandas as pd


year_order = list(range(2010, 2025))
doc_counts['year'] = pd.Categorical(doc_counts['year'], categories=year_order, ordered=True)

# base pi-chart
first_year = year_order[0]
first_data = doc_counts[doc_counts['year'] == first_year]

fig = go.Figure(
    data=[go.Pie(labels=first_data['country'], values=first_data['percentage'], hole=0.3)],
    layout=go.Layout(
        title=f'Evolution of the Percentage of Documents by Country and Year: {first_year}',
        height=800,
        width=1200
    )
)

# animated
frames = []
for year in year_order:
    year_data = doc_counts[doc_counts['year'] == year]
    frames.append(go.Frame(
        data=[go.Pie(labels=year_data['country'], values=year_data['percentage'], hole=0.3)],
        layout=go.Layout(title=f'Evolution of the Percentage of Documents by Country and Year: {year}')
    ))

fig.frames = frames

fig.update_layout(
    updatemenus=[dict(type="buttons", showactive=False, buttons=[dict(label="Play", method="animate", args=[None, {"frame": {"duration": 500, "redraw": True}, "fromcurrent": True, "transition": {"duration": 300}}])])],
)

# setting layout
fig.update_layout(
    title='Evolution of the Percentage of Documents by Country and Year',
    height=800,
    width=1200,
    showlegend=True,
)

fig.show()

# %%
# validation - percentage
yearly_percentage_sum = doc_counts.groupby('year')['percentage'].sum()
print("Yearly percentage sums:")
print(yearly_percentage_sum)
# Out:
# Yearly percentage sums:
# year
# 2010    100.0
# 2011    100.0
# 2012    100.0
# 2013    100.0
# 2014    100.0
# 2015    100.0
# 2016    100.0
# 2017    100.0
# 2018    100.0
# 2019    100.0
# 2020    100.0
# 2021    100.0
# 2022    100.0
# 2023    100.0
# 2024    100.0
# Name: percentage, dtype: float64
# /var/folders/v7/x2wdwxr928nc4dl6_lntd1rr0000gn/T/ipykernel_76819/4004461911.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
# counts - bar
year_order = list(range(2010, 2025))
doc_counts['year'] = pd.Categorical(doc_counts['year'], categories=year_order, ordered=True)

fig_counts = px.bar(
    doc_counts,
    x='country',
    y='count',
    animation_frame='year',
    animation_group='country',
    color='country',
    range_y=[0, doc_counts['count'].max()],
    title='Evolution of the Number of Documents by Country and Year',
    labels={'counts': 'Number of Documents', 'country': 'Country'}
)

fig_counts.update_layout(
    width=1200,
    height=800,
    showlegend=False,
    xaxis={'categoryorder': 'total descending'},
    transition={'duration': 500}
)

fig_counts.frames = sorted(fig_counts.frames, key=lambda frame: int(frame.name))

fig_counts.layout.updatemenus[0].buttons[0].args[1]['frame']['redraw'] = False
fig_counts.layout.updatemenus[0].buttons[0].args[1]['mode'] = 'immediate'


fig_counts.show()

# %%
# validation counts 
import plotly.express as px
import pandas as pd

doc_counts = doc_counts.sort_values(by=['year', 'count'], ascending=[True, False])
print("Sorted data by year and count:")
print(doc_counts[['year', 'country', 'count']].head())


# Group the data by year and select the top 10 countries by percentage for each year
top_10_per_year = doc_counts.groupby('year').apply(lambda x: x.nlargest(10, 'percentage')).reset_index(drop=True)

# Add a ranking column for each year to maintain country order based on percentage
top_10_per_year['rank'] = top_10_per_year.groupby('year')['percentage'].rank(ascending=False, method='first')

# Create an animated bar chart for percentages
fig_percentage = px.bar(
    top_10_per_year,
    x='country',
    y='percentage',
    animation_frame='year',
    animation_group='country',
    color='country',
    range_y=[0, doc_counts['percentage'].max()],
    title='Evolution of the Percentage of Documents by Country and Year (Top 10)',
    labels={'percentage': 'Percentage of Documents', 'country': 'Country'},
)

# Update layout
fig_percentage.update_layout(
    height=800,
    width=1200,
    showlegend=False,
    transition={'duration': 500}
)

# Sort countries by percentage rank for each year in the animation and ensure leftmost country has the highest percentage
for frame in fig_percentage.frames:
    frame.data = sorted(
        frame.data, 
        key=lambda d: top_10_per_year[
            (top_10_per_year['year'] == int(frame.name)) & 
            (top_10_per_year['country'] == d['name'])
        ]['rank'].values[0]
    )

    # Reorder x-axis based on rank (ensuring highest percentage is leftmost)
    frame.layout.xaxis.categoryorder = 'array'
    frame.layout.xaxis.categoryarray = top_10_per_year[
        top_10_per_year['year'] == int(frame.name)
    ].sort_values(by='rank')['country'].tolist()

# Show the figure
fig_percentage.show()
# Out:
# Sorted data by year and count:
#       year             country  count
# 474   2010         El Salvador      7
# 185   2010              Bosnia      6
# 1423  2010  Sub-Saharan Africa      5
# 209   2010              Brazil      4
# 425   2010             Dongnai      4
# /var/folders/v7/x2wdwxr928nc4dl6_lntd1rr0000gn/T/ipykernel_76819/1541423561.py:10: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /var/folders/v7/x2wdwxr928nc4dl6_lntd1rr0000gn/T/ipykernel_76819/1541423561.py:10: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# /var/folders/v7/x2wdwxr928nc4dl6_lntd1rr0000gn/T/ipykernel_76819/1541423561.py:13: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
